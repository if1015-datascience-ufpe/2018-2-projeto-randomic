# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from scipy.stats import linregress, t

# %%
df_main = pd.read_hdf('../../data/processed/solicitacoes156.h5', key='data', format="table")
df_pluvi = pd.read_hdf('../../data/processed/pluviometrico.h5', key='data', format="table")

# %%
dummies = pd.get_dummies(df_main['SERVICO_DESCRICAO'])
columns = dummies.columns

# %%
df_main.drop('SERVICO_DESCRICAO',axis=1,inplace=True)

# %%
df_main = pd.concat([df_main,dummies],axis=1)
df_group = df_main.groupby("DATA_DEMANDA")[columns].sum()

# %%
df_merged = df_group.join(df_pluvi.set_index("DATA"),on="DATA_DEMANDA")

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
columns_new = df_merged.columns

# %%
columns_x = [x.replace(" ","_").replace(".","").replace(",","_").replace("\\","_").replace("-","_").replace("/","_") for x in columns_new]
df_merged.columns = columns_x
columns_x.remove("INDICE")

# %%
columns_str = 'INDICE ~ ACAO_EDUC_E_INFORMATIVA + ACENDER_CIRCUITO + ANALISE_DE_PROJETO + APAGAR_CIRCUITO + APAGAR_LAMPADA + AVAL_INST_DE_CESTAS_DE_LIXO + AVALIACAO_E_PARECER_TECNICO + CAPINACAO_DE_PRACAS_AREAS_VERD + CAPINACAO_EM_LOGRADOUROS + CAPINACAO_EM_VIA_NAO_PAVIMENTADA + CAPINACAO_EM_VIA_PAVIMENTADA + COBRANCAS_E_TAXAS_IRREGULARES + COLETA_COMPUTADORES + COLETA_HOSPITALAR_IRREGULAR + COLETA_IRREGULAR_DE_LIXO + COMPOSICAO_DE_PRECOS_E_ORCAMEN + CONECTA_RECIFE + CONSERTO_DE_CALCADAS_E_MUROS + CONTROLE_TECNOLOGICO_DO_ASFALTO + CORTE_DE_RAIZES_DE_ARVORES + DANO_CAUSADO_COLETA_LIXO + DENUNCIAS_EMLURB + DESTOCA_DE_ARVORE + DOACAO_DE_COLETA_SELETIVA + ELABORACAO_DE_PROJETOS + ERRADICACAO_DE_ARVORES + ESTRUTURA_PARA_EVENTOS + ESTUDO_GEOTECNICO + EXUMACAO + FURTO_EM_TUMULOS + IDENTIFPROPIETARIO_TERRENO + IMP_COLETA_SELETIVA + IMPLANTACAO_DE_LUMINARIAS + IMPLANTACAO_DE_PEV + IMPLANTACAO_DE_POSTE + IMPLANTACAO_DE_VAO_DE_REDE + IMPLANTACAO_DE_VARRICAO + IMPLANTACAO_LAMPADA_LED + INFRA_ESTRUTURA_PARA_EVENTOS + INSP_E_LEVANT_IP___CONVENCI + INSP_E_LEVANT_IP___ESPECIAL + INST_PLACA_PROIBITIVA + INST_PROV_ + INSTPROV_ILUMINACAO_PROJETORES + INSTPROVDE_TABLADOS_E_PALANQUES + INSTALACAO_DE_CONTENEDORES_DE_LIXO + INSTALACAO_DE_PAPELEIRAS + INSTALACAO_PROVISORIA_DE_PONTO_DE_AC + INSTALACAO_PROVISORIA_DE_QUADRO + LEVANTAMENTO_TOPOGRAFICO + LIMP_DE_GALERIAS_VALETAS_SARJETAS + LIMPEZA_DE_CANAL + LIMPEZA_DE_CANALETAS + LIMPEZA_DE_COQUEIROS_PALMEIRAS + LIMPEZA_DE_ESCADARIAS + LIMPEZA_DE_LUMINARIA + LIMPEZA_DE_PRACAS + LIMPEZA_DE_PROPRIOS_MUNICIPAIS + LIMPEZA_DE_RUAS___EVENTOS + MANUT_EM_CAMPOS_QUADRAS_POLIESPORTIVAS + MANUT_EM_LAMPADA_APAGADA + MANUT_RECUP_EM_MONUMENTOS + MANUT_RELUZ + MANUTENCAO_EM_LAMPADA_APAGADA + MANUTENCAO_EM_PEV + MUDANCA_DE_PONTO_DE_CONFINAMENTO_DE_LIXO + OBRAS_DRENAGE_RECUP_PROPRIOS + OPER_TAPA_BURACO_EM_ASFALTO + PALESTRA_COLETA_SELETIVA + PANFLETAGEN_IRREGULAR_EM_VIAS_PUBLICAS + PASSARELA_DE_PEDESTRES + PINTURA_DE_MEIO_FIO + PINTURA_EM_PONTES_E_CAIS + PLANTIO_DE_ARVORES_OU_ARBUSTO + PODA_DE_ARVORES + PONTO_CRITICO_CATADOR + POSICIONAR_LUMINARIA + PROJETO_DE_ILUMINACAO + PROJETO_DE_PAVIMENTACAO_E_DRENAGEM + PROJETO_HIDROSSANITARIO + QUEDA_DE_ARVORE + REBAIXAMENTO_COPAS_DE_ARVORES + RECAPEAMENTO_ASFALTICO + RECLAMACAO_CONTENEDOR + RECLAMACOES_DIVERSAS_NECROPOLES + RECOLOCACAO_DE_MEIO_FIO + RECUP_DE_ABATIMENTO_GALERIA + RECUP_DE_BRINQUEDOS_EM_PRACAS + RECUP_DE_CANALETA_DE_ESCADARIA + RECUP_DE_ESCADARIA + RECUP_DE_PAV_PARALELEPIPEDO + RECUP_DE_PONTES_E_PONTILHOES + RECUP_EM_PAV_DE_CONCRETO + RECUPCALCADA_POR_ERRADICAO + RECUPDA_VEGETACAO_DE_PRACAS + RECUPDE_CALCADA_PUBLICA + RECUPDE_CANALETAS_DE_DRENAGEM + RECUPE_MANUT_DE_PRACA + RECUPEM_MUROS_DE_ARRIMO + RECUPERACAO_DE_PAVIMENTO_PARALELEPIPEDO + REG_COLETA_SELETIVA + REG_DE_VARRICAO_OU_ESVAZIAR_PAPELEIRA + REGULARIZAR_COLETA_DOMICILIAR + REMOCAO_DE_ANIMAIS_MORTOS_DE_GRANDE_PORTE + REMOCAO_DE_ANIMAIS_MORTOS_PEQUENOS + REMOCAO_DE_AREIA_OU_BARRO_DE_ENXURRADA + REMOCAO_DE_ENTULHOS + REMOCAO_DE_METRALHA_OU_BARRO + REMOCAO_DE_PODA_DO_CIDADAO + REMOCAO_DE_PONTO_CRITICO + REMOCAO_DE_UTILITARIOS_DOMESTICOS_GELADEIRA_SOFA_ETC + REMOCAO_MECANIZADA + REPOSTAMPA_POCO__GALER_E_PRE_MOLDADOS + REPOSICAO_DE_LUMINARIA + REPOSICAO_DESL_E_RET_DE_POSTE + REPOSICAO_VAO_DE_REDE + RETIRADA_DE_MATERIAIS___SERVICOS + ROUBO_OU_SEGURANCA_EM_CEMITERIO + SEPULTEM_COVA_ADULTO + SEPULTEM_COVA_INFANTIL + SEPULTEM_GAVETA_ADULTO + SEPULTEM_JASIDUO + TAPA_BURACO_ASFALTO_ + TAPA_BURACO_PARALELO_ + TERRAPLANAGEM_DE_RUAS + TRATAMENTO_FITOSSANITARIO + TUMULO_DE_FAMILIA + VELORIO_POPULAR + VELORIO_PRINCIPAL + VISTORIA_DE_ARVORES + VISTORIA_INTERVENÇÃO_INDEVIDA_EM_VIAS_PÚBLICAS'

# %%
model = smf.ols(columns_str,data=df_merged.reset_index())
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        QUEDA_DE_ARVORE   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Thu, 29 Nov 2018   Prob (F-statistic):                nan
# Time:                        02:19:27   Log-Likelihood:                 63041.
# No. Observations:                2504   AIC:                        -1.211e+05
# Df Residuals:                       0   BIC:                        -1.065e+05
# Df Model:                        2503
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                         4.002e-14        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-02 00:00:00')]  5.355e-12        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-03 00:00:00')]  1.291e-12        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-04 00:00:00')]  9.749e-12        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-05 00:00:00')]  9.514e-12        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-06 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-07 00:00:00')]    -0.0424        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-08 00:00:00')]    -0.1860        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-09 00:00:00')]    -0.6246        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-10 00:00:00')]    -0.3962        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-11 00:00:00')]     1.8767        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-12 00:00:00')]    -0.6994        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-13 00:00:00')]    -0.0061        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-14 00:00:00')]    -0.2324        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-15 00:00:00')]    -0.6104        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-16 00:00:00')]    -0.0687        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-17 00:00:00')]    -0.0222        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-18 00:00:00')]    -0.1395        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-19 00:00:00')]    -0.3214        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-20 00:00:00')]     1.6685        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-21 00:00:00')]    -3.0683        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-22 00:00:00')]    -2.7757        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-23 00:00:00')]    -1.7424        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-24 00:00:00')]    -1.5725        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-25 00:00:00')]     0.9151        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-26 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-27 00:00:00')]    -0.6973        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-28 00:00:00')]    -0.0101        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-29 00:00:00')]    -0.0202        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-30 00:00:00')]    -0.0101        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-01-31 00:00:00')]     0.0520        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-01 00:00:00')] -1.426e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-02 00:00:00')] -1.331e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-03 00:00:00')]    -0.0222        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-04 00:00:00')] -1.119e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-05 00:00:00')]    -0.2203        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-06 00:00:00')]    -0.2850        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-07 00:00:00')]    -0.0303        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-08 00:00:00')]    -0.0222        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-09 00:00:00')] -1.017e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-10 00:00:00')] -1.347e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-11 00:00:00')] -1.013e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-12 00:00:00')]    -0.0243        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-13 00:00:00')]    -0.0243        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-14 00:00:00')]  -1.13e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-15 00:00:00')]    -0.1476        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-16 00:00:00')]     0.9677        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-17 00:00:00')]     1.0116        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-18 00:00:00')]    -5.3817        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-19 00:00:00')]    -2.9268        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-20 00:00:00')]     0.6589        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-21 00:00:00')]     1.7190        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-22 00:00:00')]    -0.4669        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-23 00:00:00')]     1.9960        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-24 00:00:00')]     0.1207        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-25 00:00:00')]    -0.0990        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-26 00:00:00')] -1.363e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-27 00:00:00')]    -0.2607        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-28 00:00:00')]    -0.0323        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-02-29 00:00:00')]    -0.0182        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-03-01 00:00:00')]    -0.0182        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-03-02 00:00:00')]     0.9252        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-03-03 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-03-04 00:00:00')] -1.229e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2012-03
inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-23 00:00:00')]    -0.0270        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-24 00:00:00')]    -0.0741        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-25 00:00:00')]    -1.1218        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-26 00:00:00')]    -0.2695        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-27 00:00:00')]    -0.0202        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-28 00:00:00')]    -1.2363        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-29 00:00:00')]     0.0938        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-30 00:00:00')]     0.3431        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-08-31 00:00:00')]    -0.5491        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-01 00:00:00')]     0.9798        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-02 00:00:00')]    -0.6372        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-03 00:00:00')]    -0.0775        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-04 00:00:00')] -1.327e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-05 00:00:00')] -1.241e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-06 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-07 00:00:00')]     0.9798        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-08 00:00:00')] -1.123e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-09 00:00:00')]    -0.1617        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-10 00:00:00')] -1.096e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-11 00:00:00')]    -0.1381        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-12 00:00:00')]    -0.0135        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-13 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-14 00:00:00')] -1.364e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-15 00:00:00')]    -0.0135        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-16 00:00:00')]    -0.2459        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-17 00:00:00')]    -0.0472        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-18 00:00:00')]    -0.0270        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-19 00:00:00')]    -0.1718        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-20 00:00:00')]     0.9562        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-21 00:00:00')]    -0.6670        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-22 00:00:00')] -1.109e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-23 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-24 00:00:00')]    -0.1314        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-25 00:00:00')]    -0.0067        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-26 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-27 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-28 00:00:00')]    -0.2661        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-29 00:00:00')]    -0.2560        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-09-30 00:00:00')]    -0.2459        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-01 00:00:00')] -1.183e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-02 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-03 00:00:00')]  -1.33e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-04 00:00:00')]    -0.0943        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-05 00:00:00')] -1.246e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-06 00:00:00')]    -0.0270        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-07 00:00:00')]    -0.0674        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-08 00:00:00')]    -0.2796        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-09 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-10 00:00:00')] -1.327e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-11 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-12 00:00:00')] -1.236e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-13 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-14 00:00:00')] -1.383e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-15 00:00:00')] -1.338e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-16 00:00:00')]    -0.1145        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-17 00:00:00')]    -0.0472        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-18 00:00:00')]     2.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-19 00:00:00')] -1.298e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-20 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-21 00:00:00')] -1.266e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-22 00:00:00')] -1.216e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-23 00:00:00')]  -1.18e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-24 00:00:00')] -1.317e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-25 00:00:00')]  -1.19e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-26 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-27 00:00:00')] -1.364e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-28 00:00:00')] -1.256e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-29 00:00:00')] -1.249e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-30 00:00:00')] -1.291e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-10-31 00:00:00')]     0.3903        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-01 00:00:00')]    -0.0135        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-02 00:00:00')]     1.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-03 00:00:00')] -1.238e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-04 00:00:00')] -1.159e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-05 00:00:00')] -1.264e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-06 00:00:00')] -1.203e-13        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-07 00:00:00')]     3.0000        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-08 00:00:00')]     0.6626        inf          0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-09 00:00:00')]    -0.2173        inf         -0        nan         nan         nan
# DATA_DEMANDA[T.Timestamp('2018-11-10 00:00:00')] -1.218e-13        inf         -0        nan         nan         nan
# INDICE                                               0.0101        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                     2513.621   Durbin-Watson:                   2.186
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         21574592.775
# Skew:                          -3.309   Prob(JB):                         0.00
# Kurtosis:                     457.688   Cond. No.                     2.90e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 2.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
result = model.fit()
reg_lin = pd.concat([result.params,result.bse,result.tvalues,result.pvalues],
          axis=1, keys=['coef','SE','t','p-value']).sort_values("p-value")

# %%
reg_lin.to_csv("h5_1.csv",header=True, sep=',')
